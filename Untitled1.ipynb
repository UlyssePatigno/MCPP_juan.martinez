# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup

# %%
index_html = urlopen("http://www.bestbuy.com/site/searchpage.jsp?cp=1&searchType=search&id=pcat17071&nrp=15&sp=-bestsellingsort%20skuidsaas&seeAll=Operating%20System&ks=960&sc=Global&list=y&usc=All%20Categories&type=page&iht=n&browsedCategory=pcmcat138500050001&st=pcmcat138500050001_categoryid%24abcat0502000&qp=operatingsystem_facet%3DOperating%20System~Windows%207%5Eoperatingsystem_facet%3DOperating%20System~Windows%208%5Eoperatingsystem_facet%3DOperating%20System~Windows%2010%5Eoperatingsystem_facet%3DOperating%20System~Windows%2010%20Pro")

# %%
index = BeautifulSoup(index_html, "lxml")

# %%
print(index.prettify())
# Out:
# <!DOCTYPE html>
# <!-- cba=16.43.9,node=16.43.28 - Instance: 755c804580 ET:  -->
# <html lang="en-US">
#  <head>
#   <title>
#    Windows 7 All Laptops - Best Buy
#   </title>
#   <meta content="IE=Edge,chrome=1" http-equiv="X-UA-Compatible"/>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <meta content="no-cache" http-equiv="pragma"/>
#   <meta content="no-cache" http-equiv="cache-control"/>
#   <meta content="-1" http-equiv="expires"/>
#   <meta content="All Laptops page 1" name="keywords"/>
#   <meta content="Shop for All Laptops at Best Buy. Find low everyday prices and buy online for delivery or in-store pick-up." name="description"/>
#   <meta content="width=1024" name="viewport"/>
#   <meta content="telephone=no" name="format-detection"/>
# ...

# %%
index.find_all('img', {"class": "b-lazy img-responsive"})

#index.find_all('img')
# Out:
# [<img alt="Latest innovation. Black stainless steel appliances. Kitchen with black stainless steel appliance suite." class="b-lazy img-responsive" data-src="http://pisces.bbystatic.com//BestBuy_US/store/ee/2016/app/misc/ug_blackstainless_153217.jpg;maxHeight=231;maxWidth=381" src="..."/>,
#  <img alt="Explore Magnolia Home Theater" class="b-lazy img-responsive" data-src="http://pisces.bbystatic.com//BestBuy_US/en_US/images/global/header/ubergrapic-magnolia-147125.jpg;maxHeight=231;maxWidth=381" src="..."/>,
#  <img alt="Microsoft Surface. The most productive devices on the planet. Shop Surface. 2-in-1 laptop and tablet." class="b-lazy img-responsive" data-src="http://pisces.bbystatic.com//BestBuy_US/store/ee/2016/com/pr/SOL-273-surface/uberNav_surface.jpg;maxHeight=231;maxWidth=381" src="..."/>,
# ...
